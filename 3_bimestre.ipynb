# %% [markdown]
# <a href="https://colab.research.google.com/github/l3otome/Aula-de-PA--1c-informatica-para-internet/blob/main/3_bimestre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#exercicio 1
# Crie uma lista contendo 05 nomes de alunos :
#mostre a lista completa
#mostre o primeiro nome
# mostre o ultimo nome
# mostre a quantidade de alunos
alunos = ["leo","João","lucas","pyetro","Heitor"]
print(alunos)
print(alunos[0])
print(alunos[-1])
print(len(alunos))
# Out:
# ['leo', 'João', 'lucas', 'pyetro', 'Heitor']
# leo
# Heitor
# 5

# %%
#Exercicio 2
#crie uma lista vazia chamada fruta
# utilisando append (),adicione 5 frutas informada pelo usuario
# ao final exiba a lista por completo
frutas = []
fru = input( "digite uma fruta: ")
fru2 = input("digite outra: ")
fru3 = input("digite outra: ")
fru4 = input("diigite outra: ")
fru5 = input("diigite outra: ")
frutas.append (fru )
frutas.append (fru2)
frutas.append (fru3)
frutas.append (fru4)
frutas.append (fru5)
print(frutas6)
# Out:
# digite uma fruta: 1
# digite outra: 2
# digite outra: 3
# diigite outra: 4
# diigite outra: 5
# ['1', '2', '3', '4', '5']

# %%
# exercicio 03
#considere a lista

numeros =[ 10,25,8,42,15,30,7 ]

#utilizando for mostre cada numero da lista
print("Todos os números na lista:")

for numeros in numeros:

  print(numeros)

  if numeros < 20:
     print("numeros maiores que 20")



#mostre os numeros maiores que 20
# Out:
# Todos os números na lista:
# 10
# numeros maiores que 20
# 25
# 8
# numeros maiores que 20
# 42
# 15
# numeros maiores que 20
# 30
# 7
# numeros maiores que 20

# %%
import math

#execicio 4
#crie uma lista contendo 10 numeros inteiros
#percorara a lista e informe quais numeros sao pares e quais sao impares
#ex :4 e par

numeros = [-15, -7, 0, 1, 3, 8, 12, 25, 50]

for num in numeros:
    if num % 2 == 0:
        print(f"{num} é par")
    else:
        print(f"{num} é ímpar")
# Out:
# -15 é ímpar
# -7 é ímpar
# 0 é par
# 1 é ímpar
# 3 é ímpar
# 8 é par
# 12 é par
# 25 é ímpar
# 50 é par

# %%
#exercicio 05
#considere
#faça um programa que percorra a lista e calcule a soma todos os valores
valores  = [100,250,80,120,]
somatotal = 0
for num in valores:
    somatotal += num
print(f"A soma de todos os valores é: {somatotal}")
# Out:
# A soma de todos os valores é: 550

# %%
# exercicio 06
#considere
#mostre a menor nota
#mostre a maior nota
#mostre a media das notas
notas = [7.5, 8.0, 6.5, 9.0, 5.5]

print("Menor nota:", min(notas))
print("Maior nota:", max(notas))
print("Média das notas:", sum(notas) / len(notas))
# Out:
# Menor nota: 5.5
# Maior nota: 9.0
# Média das notas: 7.3

# %%
 # exercicio 07
 #crie umas lista vazia chamada produto peça para o usuario cadastras 5 produtos utilizando for motre os produtos numerados
 # 1- arroz
 # 2- feijão
 # 3- leite
 produto = []

for i in range(5):
    nome = input("Digite o nome do produto: ")
    produto.append(nome)

print("Produtos cadastrados:")

for i in range(5):
    print(i + 1, "-", produto[i])
# Out:
# Digite o nome do produto: feijao
# Digite o nome do produto: leite
# Digite o nome do produto: arroz
# Digite o nome do produto: gel
# Digite o nome do produto: sei la
# Produtos cadastrados:
# 1 - feijao
# 2 - leite
# 3 - arroz
# 4 - gel
# 5 - sei la

# %%
#exercicio 08
# considere
alunos=["ana","calos", "maria","pedro","joão "]
#peça para o usuario digitar um nome
nome = input("Digite um nome: ")

if nome in alunos:
    print("O nome está na lista")
else:
    print("O nome não está na lista")
# Out:
# Digite um nome: leo
# O nome não está na lista!

# %%
from re import X
# execicio 9
#lista vazia de numeros pedir 10 numeros
# uma de par e outra lista de impar
#se pare o valor de cada lista
lista = []
par =[]
impares =[]
for i in range (10):
  numeros =(int(input("digite um numero: ")))
  lista.append (numeros)
  if numeros% 2 == 0:
    par.append (numeros)
  else:
    impares.append (numeros)

print(f" Lista de numero pares: {par}")
print(f" Lista de numeros impares {impares}")
print(f" Lista de numeros: {lista}")
# Out:
# digite um numero: 21
# digite um numero: 34
# digite um numero: 56
# digite um numero: 78
# digite um numero: 77
# digite um numero: 67
# digite um numero: 33
# digite um numero: 22
# digite um numero: 11
# digite um numero: 999
#  Lista de numero pares: [34, 56, 78, 22]
#  Lista de numeros impares [21, 77, 67, 33, 11, 999]
#  Lista de numeros: [21, 34, 56, 78, 77, 67, 33, 22, 11, 999]

# %%
notas = []
for i in range(1,6):
  nota = float(input("digite a nota do aluno: "))
  notas.append(nota)

maior = len([n for n in notas if n >= 6])
menor = len([n for n in notas if n < 6])

print(f'Todas as notas: {notas}')
print(f'Maior nota: {max(notas)}')
media_turma = sum(notas)/len(notas)
print(f"media da turma: {media_turma:.2f}")
print(f" alunos com media maior ou  6: {maior}")
print(f" alunos com media menor que 6: {menor}")
# Out:
# Digite a nota do aluno: 10
# Digite a nota do aluno: 666
# Digite a nota do aluno: 555
# Digite a nota do aluno: 333
# Digite a nota do aluno: 222
# Todas as notas: [10.0, 666.0, 555.0, 333.0, 222.0]
# Maior nota: 666.0
# Média da turma: 357.20
# Quantidade de alunos com média maior ou igual a 6: 5
# Quantidade de alunos com média menor que 6: 0
