# %% [markdown]
# <a href="https://colab.research.google.com/github/l3otome/Aula-de-PA--1c-informatica-para-internet/blob/main/HelloWord_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
aula de PA

# %%
print("hello word")
#tipos numericos
nome = 'Leonardo'
idade = '15' #int
altura ='1,67' #float
numero_complexo = 2 + 3j #complex
# Out:
# hello word

# %% [markdown]
#   algoritimo que calcula o quadrado
#   # Entrada
#   ler o lado
#
#   # Processamento
#   multiplicar lado pelo  lado
#    # Saida
#    mostrar resutado da multiplicaçao

# %%
# Entrada

lado = 6

# Processamento

quadrado = lado * lado
# Saida

print (f"total da area do quadrado: {quadrado}")
# Out:
# total da area do quadrado: 36

# %% [markdown]
# escrever um algoritimo e o programa que calcula a area de de uma sala
#
#
#
# # entrada
# ler comprimento
# ler largura
#
#
#  # processamento
# mutiplicar comprimento pela altura
#
#
#
#  # saida
#
# mostrar total da area

# %%
#entrada

comprimento = 7

altura = 3


#processamento

area = comprimento * altura

#saida

print (f"total da area:{area}")
# Out:
# total da area:21

# %% [markdown]
# Faça um programa que recebe 04 notas de aluno e calcula a media e depois mostra a media
# # entrada
# nota1
#
# nota2
#
# nota3
#
# nota4
#
# # processamento
#
# calcular media das notas
#
#  # saida
#  mostrar media

# %%
#entrada
nota1 = 10
nota2 = 7
nota3 = 8
nota4 = 5


media = (nota1 + nota2 + nota3 + nota4) /4

#saida
print (media)
# Out:
# 7.5

# %%
# Calcular área do retangulo

# entrada
comprimento = float(input("digite o comprimento : "))
altura = float(input("digite da altura :"))

# processamento
area = comprimento * altura

 # saida

print (f"total da area: {area}")
# Out:
# digite o comprimento :8
# digite da altura :5
# total da area: 40.0

# %%
# fazer um cadastro simples, com o nome e a idade.

# entrada: nome e idade

#processamento :armazena  os dados

# saida :mensagen de boas vindas
nome = input("digite seu nome")
idade = input("digite sua idade")

print(f"ola {nome} seja bem vindo!")
print(f"voce tem {idade} anos")
# Out:
# digite seu nome leonardo
# digite sua idade 15
# ola  leonardo seja bem vindo!
# voce tem  15 anos

# %% [markdown]
# # fazer um programa  que converte a temperatura de celsius para fahrenheit.
#
# entrada : graus cesius
#
#
# prosesamento : converter temperatura para
#
#
# mostrar temperatura em farenheit
# f =(c * 9/5) + 32

# %%
# entrada
celsius = float(input("digite a temperatura em celsius :"))

# procesamento

farrenheit = (celsius * 9/5) + 32

# saida

print(f"a temperatura em farenheit é {farrenheit} ")
# Out:
# digite a temperatura em celsius :33
# a temperatura em farenheit é 91.4

# %%
# Operadores aritiméticos


# Soma de dois numeros

# Entrada
a =int(input("digite o primeiro numero: "))
b =int(input("digite o segundo numero: "))

# Processamento

# Soma  de dois numeros
soma = a + b
subtraçao = a - b
mutiplicaçao = a * b
divisao = a / b
div_int = a//b


# Saida
print("")
print("------------soma-----------")
print(f"a soma de {a} + {b} = {soma}")
print("")
print("------------SUBTRAÇÃO---------")
print(f"a subtração de {a} - {b} = {subtraçao}")
print("")
print("------------MULTIPLICAÇÃO-------")
print(f"a Mutipicação de {a} * {b} = {mutiplicaçao}")
print("")
print("------------DIVISÃO--------")
print(f"a divisão de {a} / {b} = {divisao}")
print("")
print("------------DIVISÃO INTEIRA--------")
print(f"a divisão inteira de {a} // {b} = {div_int}")
print("---------------------------")
# Out:
# digite o primeiro numero: 21
# digite o segundo numero: 12
#
# ------------soma-----------
# a soma de 21 + 12 = 33
#
# ------------SUBTRAÇÃO---------
# a subtração de 21 - 12 = 9
#
# ------------MULTIPLICAÇÃO-------
# a Mutipicação de 21 * 12 = 252
#
# ------------DIVISÃO--------
# a divisão de 21 / 12 = 1.75
#
# ------------DIVISÃO INTEIRA--------
# a divisão inteira de 21 // 12 = 1
# ---------------------------

# %%
# Entrada
Num1 = int(input("digite o primeiro numero: "))
Num2 = int(input("digite o segundo numero: "))

#procesamento
igual = Num1 == Num2 #IGUAL
maior = Num1 > Num2 #MAIOR
menorigual= Num1 >= Num2 #MENOR IGUAL
Maiorrigual = Num1 <= Num2 #MAIOR IGUAL
menor = Num1 < Num2 #MENOR
diferente = Num1 != Num2 #diferente

  # saida
print (igual)
print (maior)
print (menor)
print (diferente)
# Out:
# digite o primeiro numero: 999
# digite o segundo numero: 5555
# False
# False
# True
# True

# %%
a = int(input("digite o primeiro numero: "))
b = int(input("digite o segundo numero: "))

if a > b:
    print(f"{a} é maior que {b}")
else:
    print(f"{b} é maior que {a}")
# Out:
# digite o primeiro numero: 21
# digite o segundo numero: 12
# 21 é maior que 12

# %%
 # Escrever um programa que verifica se o usuario é maior de idade.
 nome = input("digite seu nome: ")
 idade = int(input("digite sua idade: "))

 if idade > 18:
    print(f"{nome} você é maior de idade")
 else:
    print(f"{nome} você e menor de idade")
# Out:
# digite seu nome: leo
# digite sua idade: 15
# leo você e menor de idade

# %%
num1 = int(input("digite um numero: "))

if num1 % 2 == 0:

    print(f"{num1} é par")

else:

  print (f"{num1} é impar")
# Out:
# digite um numero: 4500
# 4500 é par

# %%
nome  = input("digite seu nome: ")
senha = input("digite sua senha: ")

if senha == "12345":
    print("acesso permitido")

else:
    print("acesso negado")
# Out:
# digite seu nome: Leo
# digite sua senha: 3333
# acesso negado

# %%
num1 = int(input("digite um numero: "))

if num1 > 18:

    print("maior")

else:

    print("menor")
# Out:
# digite um numero: 90
# maior

# %%
valor = float(input("digite um valor da sua compra: "))

if valor > 100:

  print ("desconto de 10%")
  print (valor * 0.9)


else:

  print("sem desconto")
# Out:
# digite um valor da sua compra: 5555
# desconto de 10%
# 4999.5

# %%
 # Escrever um programa que o aluno digita as 4 notas dos bimestre eo programa calcula  a média  e mostra na saida se o aluno foi aprovado ou de recuperação
 nota1 = float(input("digite a primeira nota: "))
 nota2 = float(input("digite a segunda nota: "))
 nota3 = float(input("digite a terceira nota: "))
 nota4 = float(input("digite a quarta nota: "))

 media = (nota1 + nota2 + nota3 + nota4) / 4
 if media >= 7:

    print(" parabens você foi aprovado")

  elif media >= 5 :

    print("voce esta de recuperação")

    else:

    print(f"voce foi reprovado sua media foi : {media }")
# Out:
#   File "<tokenize>", line 12
#     elif media >= 5 :
#     ^
# IndentationError: unindent does not match any outer indentation level
